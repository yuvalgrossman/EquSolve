# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvalgrossman/EquSolve/blob/master/smbol_seperation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone http://github.com/yuvalgrossman/EquSolve
# Out:
# Cloning into 'EquSolve'...
# ...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 75 (delta 23), reused 29 (delta 5), pack-reused 0
# Unpacking objects: 100% (75/75), done.

# %%
import EquSolve.Utils.symbols_seperation as ss
import cv2

# %%
data_path = 'EquSolve/DataSets/hand_written_eqs/'
fn = data_path + 'single_eq1.jpg'
img = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)

# %%
# first lets find the connected components below some threshold:
cc = ss.find_cc(img, threshold=150)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
# now lets unite the two parts of the equal sign:
cc = ss.find_cc(img, threshold=150)
cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
fn = data_path + 'single_eq2.jpg'
img = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)

cc = ss.find_cc(img, threshold=150)
cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
np.median(img.reshape(-1))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# 202.0

# %%
# it missed the "-" sign. we need to take higher threshold:
cc = ss.find_cc(img, threshold=160)
cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
fn = data_path + 'single_eq3.jpg'
img = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)

cc = ss.find_cc(img, threshold=140)
cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
#but for complete images, it doesn't behave well:
fn = data_path + 'example1.jpg'
img = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)

cc = ss.find_cc(img, threshold=150)
cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
# for multi-rows image the unite algorithm doesn't work well. without the unite:
cc = ss.find_cc(img, threshold=150)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
fn = data_path + 'example2.png'
img = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)

cc = ss.find_cc(img, threshold=100)
# cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
fn = data_path + 'example3.jpg'
img = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)

cc = ss.find_cc(img, threshold=100)
# cc = ss.unite_symbols_with_gap(cc)
ss.plot_detections(img, cc)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
